# %%
# !pip install azure-ai-ml promptflow
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
#   Cell In[5], line 1
#     az ad sp create-for-rbac --name "my-ml-app" --role "Contributor" --scopes /subscriptions/YOUR_SUBSCRIPTION_ID
#        ^
# SyntaxError: invalid syntax

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

# Azure subscription details
subscription_id = "3b608a14-90b7-42d9-82e2-77c947974137"
resource_group = "autograder-joshyip-testcase"
workspace_name = "autograder-549-project"

# Authenticate using DefaultAzureCredential (make sure you're logged in)
credential = DefaultAzureCredential()
ml_client = MLClient(credential, subscription_id, resource_group, workspace_name)

print("Connected to Azure ML Workspace:", ml_client.workspace_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 10
#       7 workspace_name = "autograder-549-project"
#       9 # Authenticate using DefaultAzureCredential (make sure you're logged in)
# ---> 10 credential = DefaultAzureCredential()
#      11 ml_client = MLClient(credential, subscription_id, resource_group, workspace_name)
#      13 print("Connected to Azure ML Workspace:", ml_client.workspace_name)
#
# File c:\Users\MHS\Desktop\PROJECTS\ml-bu-autograder\venv\Lib\site-packages\azure\identity\_credentials\default.py:149, in DefaultAzureCredential.__init__(self, **kwargs)
#     147 within_dac.set(True)
#     148 if not exclude_environment_credential:
# --> 149     credentials.append(EnvironmentCredential(authority=authority, _within_dac=True, **kwargs))
#     150 if not exclude_workload_identity_credential:
# ...
